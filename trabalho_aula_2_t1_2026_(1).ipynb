# %% [markdown]
# <a href="https://colab.research.google.com/github/viktoruebelhart/pos_facens/blob/main/trabalho_aula_2_t1_2026_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercício 1
#
# Crie uma lista de números inteiros. Em seguida, utilize a função `map` (sem loops explícitos) para criar uma nova lista onde cada número da lista original é multiplicado por 2. Por fim, imprima a nova lista.

# %%
# Digite seu código aqui
lista = [1, 2, 3, 4, 5]
nova_lista = list(map(lambda x: x * 2, lista))
print(nova_lista)
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# ## Exercício 2
#
# Dada uma lista de palavras, utilize a função `filter` (sem loops explícitos) para criar uma nova lista contendo apenas as palavras que têm mais de 5 caracteres. Imprima a lista filtrada.

# %%
# Digite seu código aqui
palavras = ["oi", "gato", "elefante", "passarinho", "tartaruga"]
palavras_5 = list(filter(lambda x: len(x) > 5, palavras))

print("lista de palavras:", palavras)
print("lista de palavras com mais de 5 caracteres:", palavras_5)
# Out:
# lista de palavras: ['oi', 'gato', 'elefante', 'passarinho', 'tartaruga']
# lista de palavras com mais de 5 caracteres: ['elefante', 'passarinho', 'tartaruga']

# %% [markdown]
# ## Exercício 3
#
# Usando `functools.reduce`, calcule o produto de todos os números em uma lista de inteiros. Você precisará importar `reduce` de `functools`. Imprima o resultado.

# %%
# Digite seu código aqui
from functools import reduce
lista = [1, 2, 3, 4, 5, 10, 2]
produto = reduce(lambda x, y: x * y, lista)
print(produto)
# Out:
# 2400

# %% [markdown]
# ## Exercício 4
#
# Dada uma lista de números, use uma combinação de `filter` e `map` (e funções `lambda` anônimas) para primeiro filtrar apenas os números pares e, em seguida, elevar cada um desses números pares ao quadrado. Imprima a lista resultante.

# %%
# Digite seu código aqui
lista = [1, 2, 3, 4, 5, 10, 2]
pares = list(filter(lambda x: x % 2 == 0, lista))
print("Lista de Pares: ", pares)
ao_quadrado = list(map(lambda x: x**2, pares))
print("Lista de Pares²: ", ao_quadrado)
# Out:
# Lista de Pares:  [2, 4, 10, 2]
# Lista de Pares²:  [4, 16, 100, 4]

# %% [markdown]
# ## Exercício 5
#
# Crie uma função Python chamada `aplicar_operacao` que receba duas coisas como argumentos: uma função (`operacao`) e uma lista de números (`numeros`). `aplicar_operacao` deve aplicar a `operacao` a cada número na lista e retornar uma nova lista com os resultados. Teste sua função passando-lhe uma função `lambda` que adiciona 10 a um número e uma lista de números. Imprima a lista resultante.

# %%
# Digite seu código aqui
def aplicar_operacao(operacao, numeros):
    return list(map(operacao, numeros))

numeros = [1, 2, 3, 4, 5, 10, 2]
nova_lista = aplicar_operacao(lambda x: x + 10, numeros)
print(nova_lista)
# Out:
# [11, 12, 13, 14, 15, 20, 12]

# %% [markdown]
# ## Exercício 6
#
# Crie uma função em Python chamada `par_ou_impar_arquivo` que receba um número inteiro como entrada. Esta função deve iterar de 1 até o número fornecido. Para cada número no intervalo, verifique se ele é par ou ímpar usando uma condicional. Em seguida, escreva em um arquivo de texto chamado `resultado_exercicio1.txt` cada número e sua classificação ("é par" ou "é ímpar") em linhas separadas.

# %%
def par_ou_impar_arquivo(numero):
    with open("resultado_exercicio1.txt", "w") as arquivo:
        for i in range(1, numero):
            if i % 2 == 0:
                arquivo.write(f"{i} é par\n")
            else:
                arquivo.write(f"{i} é ímpar\n")

numero = 20
par_ou_impar_arquivo(numero)

# %% [markdown]
# ## Exercício 7
#
# Crie uma função Python chamada `somar_numeros_arquivo` que receba dois argumentos: o nome de um arquivo de texto de entrada e o nome de um arquivo de texto de saída. O arquivo de entrada conterá números, um por linha. A função deve ler esses números, calcular a soma deles e escrever o resultado da soma em uma nova linha no arquivo de saída. A função deve tratar possíveis erros, como o arquivo de entrada não ser encontrado ou linhas que não contenham números válidos.

# %%
def somar_numeros_arquivo(arquivo_entrada, arquivo_saida):
    try:
        soma = 0

        with open(arquivo_entrada, "r") as entrada:
            for linha in entrada:
                try:
                    numero = float(linha.strip())
                    soma += numero
                except ValueError:
                    print(f"Linha ignorada (não é número válido): {linha.strip()}")

        with open(arquivo_saida, "w") as saida:
            saida.write(f"A soma dos números é: {soma}\n")

        print(f"A soma dos números é: {soma}")

    except FileNotFoundError:
        print("Erro: arquivo de entrada não encontrado.")

somar_numeros_arquivo("arquivo_entrada.txt", "arquivo_saida.txt")
# Out:
# Linha ignorada (não é número válido): é não
# A soma dos números é: 45.0

# %% [markdown]
# ## Exercício8
#
# Crie uma função Python chamada `classificar_numeros_em_arquivo` que receba como argumentos o nome de um arquivo de texto de entrada e o nome de um arquivo de texto de saída. O arquivo de entrada conterá números, um por linha. A função deve ler esses números, classificar cada um como "Positivo", "Negativo" ou "Zero" e escrever o número original e sua classificação em linhas separadas no arquivo de saída exemplo -10: Negativo. A função deve tratar possíveis erros, como o arquivo de entrada não ser encontrado ou linhas que não contenham números válidos.

# %%
# Digite seu código aqui
def classificar_numeros_em_arquivo (arquivo_entrada, arquivo_saida):
    try:
        with open(arquivo_saida, "w") as saida:
          with open(arquivo_entrada, "r") as entrada:
              for i, linha in enumerate(entrada, start=1):
                  try:
                    numero = float(linha.strip())
                    if numero > 0:
                      saida.write(f"{linha.strip()} Positivo\n")
                    elif numero < 0:
                      saida.write(f"{linha.strip()} Negativo\n")
                    elif numero == 0:
                      saida.write(f"{linha.strip()} Zero\n")
                  except ValueError:
                    print(f"Linha {i} ignorada (não é número válido): {linha.strip()}")


    except FileNotFoundError:
        print("Erro: arquivo de entrada não encontrado.")
classificar_numeros_em_arquivo("arquivo_entrada.txt", "arquivo_saida.txt")
# Out:
# Linha 3 ignorada (não é número válido): é não
# Linha 6 ignorada (não é número válido): outro

# %% [markdown]
# ## Exercício 9
#
# Crie uma função Python chamada `processar_dados_alunos` que receba como argumento o nome de um arquivo de texto. Este arquivo conterá dados de alunos no formato "Nome,Nota1,Nota2,Nota3", uma linha por aluno. Dentro da função, abra o arquivo para leitura. Para cada linha do arquivo, leia o nome do aluno e suas três notas. Calcule a média das três notas para cada aluno. Determine se o aluno foi aprovado (média >= 7.0) ou reprovado. Crie um novo arquivo de texto chamado "resultados_alunos.txt". Escreva no novo arquivo, para cada aluno, o nome e sua situação (Aprovado ou Reprovado) no formato "Nome: Situação". A função deve tratar possíveis erros de arquivo não encontrado e linhas com formato inválido ou notas não numéricas.

# %%
def processar_dados_alunos(nome_arquivo):
    try:
        with open(nome_arquivo, "r", encoding="utf-8") as arquivo:
          with open("resultados_alunos.txt", "w", encoding="utf-8") as resultado_arquivo:

            for linha in arquivo:
                try:
                    # Remove espaços e quebra de linha
                    linha = linha.strip()

                    # Divide os dados
                    partes = linha.split(",")

                    # Verifica se tem 4 partes (nome + 3 notas)
                    if len(partes) != 4:
                        print(f"Linha inválida ignorada: {linha}")
                        continue

                    nome = partes[0]

                    # Converte notas para float
                    notas = list(map(float, partes[1:]))

                    # Calcula média
                    media = sum(notas) / len(notas)

                    # Verifica situação
                    if media >= 7:
                        situacao = "Aprovado"
                    else:
                        situacao = "Reprovado"

                    # Escreve no arquivo
                    resultado_arquivo.write(f"{nome}: {situacao}\n")

                except ValueError:
                    print(f"Erro de conversão ignorado: {linha}")

    except FileNotFoundError:
        print("Arquivo não encontrado!")


# Teste
processar_dados_alunos("lista_aluno.txt")

# %% [markdown]
# ## Exercício 10
#
# Crie uma função Python chamada `processar_vendas_manual` que receba como argumentos o nome de um arquivo CSV de entrada e o nome de um arquivo CSV de saída. O arquivo de entrada conterá dados de vendas com as colunas "Produto", "Quantidade" e "Preco_Unitario".
#
# Dentro da função, abra o arquivo CSV de entrada para leitura. Leia cada linha do arquivo, **manualmente (sem usar bibliotecas como `csv`)** dividindo a linha pelas vírgulas. Para cada item de venda, calcule o "Valor_Total" multiplicando a "Quantidade" pelo "Preco_Unitario". Certifique-se de converter "Quantidade" para inteiro e "Preco_Unitario" para float.
#
# Crie um novo arquivo CSV de saída. Para cada linha do arquivo de entrada , escreva no arquivo de saída as informações originais ("Produto", "Quantidade", "Preco_unitario") e o "Valor_Total" calculado, separando os valores por vírgulas.
#
# A função deve tratar possíveis erros, como arquivo de entrada não encontrado, linhas com formato inválido ou valores não numéricos para Quantidade e Preco_Unitario.

# %%
# Digite seu código aqui
# CSV Entrada - Colunas "Produto", "Quantidade" e "Preco_Unitario"
def processar_vendas_manual(arquivo_entrada_csv, arquivo_saida_csv):
    try:
        with open(arquivo_entrada_csv, "r", encoding="utf-8") as entrada:
            linhas = entrada.readlines()

        with open(arquivo_saida_csv, "w", encoding="utf-8") as saida:
            # Escreve o cabeçalho no arquivo de saída
            saida.write("Produto,Quantidade,Preco_Unitario,Valor_Total\n")


            for numero_linha, linha in enumerate(linhas, start=1):
                linha = linha.strip()

                # Ignorar linha vazia
                if not linha:
                    continue

                partes = linha.split(";")

                # Validar se tem exatamente 3 colunas
                if len(partes) != 3:
                    print(f"Linha {numero_linha} ignorada (formato inválido): {linha}")
                    continue

                produto, quantidade, preco = partes

                try:
                    quantidade = int(quantidade)
                    preco = float(preco)
                    valor_total = quantidade * preco

                    # Escreve no arquivo de saída
                    saida.write(f"{produto},{quantidade},{preco},{valor_total}\n")

                except ValueError:
                    print(f"Linha {numero_linha} ignorada (valores inválidos): {linha}")

    except FileNotFoundError:
        print("Erro: arquivo de entrada não encontrado.")

processar_vendas_manual("produtos_ex10.csv", "saida_ex10.csv")
# Out:
# Linha 1 ignorada (valores inválidos): ﻿Produto;Quantidade;Preco_Unitario
