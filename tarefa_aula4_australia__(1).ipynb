# %% [markdown]
# <a href="https://colab.research.google.com/github/viktoruebelhart/pos_facens/blob/main/tarefa_aula4_australia__(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Descrição do Dataset — Rain in Australia (weatherAUS)
#
# **Fonte:** Kaggle — "Rain in Australia" (jsphyg/weather-dataset-rattle-package),
# dados originais do Bureau of Meteorology (BOM) da Austrália.
#
# **Contexto:** ~10 anos de observações meteorológicas diárias coletadas em
# diversas estações espalhadas pela Austrália.
#
# **Tamanho:** 145.460 linhas x 23 colunas
#
# **Variável alvo:** `RainTomorrow` (Yes/No) — indica se choveu no dia seguinte.
#
#
# **Principais colunas:**
# - `Date` — data da observação
# - `Location` — cidade/estação meteorológica
# - `MinTemp` / `MaxTemp` — temperatura mínima/máxima do dia (°C)
# - `Rainfall` — quantidade de chuva no dia (mm)
# - `Evaporation` — evaporação (mm)
# - `Sunshine` — horas de sol no dia
# - `WindGustDir` / `WindGustSpeed` — direção/velocidade da rajada de vento mais forte
# - `WindDir9am` / `WindDir3pm` — direção do vento às 9h/15h
# - `WindSpeed9am` / `WindSpeed3pm` — velocidade do vento às 9h/15h
# - `Humidity9am` / `Humidity3pm` — umidade relativa às 9h/15h (%)
# - `Pressure9am` / `Pressure3pm` — pressão atmosférica às 9h/15h (hPa)
# - `Cloud9am` / `Cloud3pm` — cobertura de nuvens às 9h/15h (oktas, 0-8)
# - `Temp9am` / `Temp3pm` — temperatura às 9h/15h (°C)
# - `RainToday` — choveu hoje? (Yes/No)
# - `RainTomorrow` — choveu amanhã? (Yes/No) — **alvo**

# %% [markdown]
# ## **Importando as Bibliotecas/ Dados**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/weatherAUS.csv')

df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %% [markdown]
# # I. Análise Exploratória Geral
#
# 1. Quantas linhas e colunas tem o dataset?
# 2. Qual a porcentagem de nulos?
# 3. Qual o tipo de cada coluna?
# 4. Existem colunas que podemos remover?
# 5. Os tipos de coluna estão adequados para os tipos de variáveis?
# 6. Temos dados duplicados?
# 7. Qual a média, desvio padrão e amplitude das colunas numéricas?

# %% [markdown]
# ## 1. Quantas linhas e colunas tem o dataset?

# %%
#1
df.shape
# Out:
# (145460, 23)

# %% [markdown]
# ## 2. Qual a porcentagem de nulos?

# %%
#2
df_nulos = (df.isnull().sum()/df.shape[0]).sort_values(ascending=False)*100
df_nulos
# Out:
# Sunshine         48.009762
# Evaporation      43.166506
# Cloud3pm         40.807095
# Cloud9am         38.421559
# Pressure9am      10.356799
# Pressure3pm      10.331363
# WindDir9am        7.263853
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# Humidity3pm       3.098446
# WindDir3pm        2.906641
# Temp3pm           2.481094
# RainTomorrow      2.245978
# Rainfall          2.241853
# RainToday         2.241853
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# WindSpeed9am      1.214767
# Temp9am           1.214767
# MinTemp           1.020899
# MaxTemp           0.866905
# Date              0.000000
# Location          0.000000
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df['RainTomorrow_num'] = df['RainTomorrow'].map({'No': 0, 'Yes': 1})

colunas_interesse = ['Sunshine', 'Evaporation', 'Cloud9am', 'Cloud3pm', 'RainTomorrow_num']
corr = df[colunas_interesse].corr()

plt.figure(figsize=(6, 5))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlação: Sunshine/Evaporation/Cloud9am/Cloud3pm x RainTomorrow')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Qual o tipo de cada coluna?

# %%
#3
df.dtypes
# Out:
# Date                 object
# Location             object
# MinTemp             float64
# MaxTemp             float64
# Rainfall            float64
# Evaporation         float64
# Sunshine            float64
# WindGustDir          object
# WindGustSpeed       float64
# WindDir9am           object
# WindDir3pm           object
# WindSpeed9am        float64
# WindSpeed3pm        float64
# Humidity9am         float64
# Humidity3pm         float64
# Pressure9am         float64
# Pressure3pm         float64
# Cloud9am            float64
# Cloud3pm            float64
# Temp9am             float64
# Temp3pm             float64
# RainToday            object
# RainTomorrow         object
# RainTomorrow_num    float64
# dtype: object

# %% [markdown]
# ## 4. Existem colunas que podemos remover?

# %% [markdown]
# Podemos analisar em remover as colunas, Sunshine (48%), Evaporation (43%), Cloud3pm (40,8%) e Cloud9am (38,4%) — todas acima de ~35-40% de nulos.

# %% [markdown]
# ## 5. Os tipos de coluna estão adequados para os tipos de variáveis?

# %% [markdown]
# Nem todos. Rodando df.dtypes de novo, dá pra separar em três grupos:
#
# Corretos: as numéricas contínuas (MinTemp, MaxTemp, Rainfall, WindGustSpeed, Humidity9am/3pm, Pressure9am/3pm, Temp9am/3pm etc.) já estão como float64, que é adequado.

# %% [markdown]
# Vai precisar de ajuste antes do modelo:
#
# RainToday e RainTomorrow são object com valores "Yes"/"No" — pros modelos (regressão logística, árvore) precisam virar binário (0/1), isso é obrigatório.

# %%
# Date -> datetime (antes de extrair Month/Season)
df['Date'] = pd.to_datetime(df['Date'])

# Categóricas de baixa cardinalidade -> category
for col in ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm']:
    df[col] = df[col].astype('category')

# Alvo e RainToday -> binário 0/1
df['RainToday'] = df['RainToday'].map({'No': 0, 'Yes': 1})
df['RainTomorrow'] = df['RainTomorrow'].map({'No': 0, 'Yes': 1})

print(df.dtypes)
# Out:
# Date                datetime64[ns]
# Location                  category
# MinTemp                    float64
# MaxTemp                    float64
# Rainfall                   float64
# Evaporation                float64
# Sunshine                   float64
# WindGustDir               category
# WindGustSpeed              float64
# WindDir9am                category
# WindDir3pm                category
# WindSpeed9am               float64
# WindSpeed3pm               float64
# Humidity9am                float64
# Humidity3pm                float64
# Pressure9am                float64
# Pressure3pm                float64
# Cloud9am                   float64
# Cloud3pm                   float64
# Temp9am                    float64
# Temp3pm                    float64
# RainToday                  float64
# RainTomorrow               float64
# RainTomorrow_num           float64
# dtype: object

# %% [markdown]
# ## 6. Temos dados duplicados?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Não temos dados duplicados

# %% [markdown]
# ## 7. Qual a média, desvio padrão e amplitude das colunas numéricas?

# %%
df.describe().T
# Out:
#                      count                           mean  \
# Date                145460  2013-04-04 21:08:51.907053568
# MinTemp           143975.0                      12.194034
# MaxTemp           144199.0                      23.221348
# Rainfall          142199.0                       2.360918
# Evaporation        82670.0                       5.468232
# Sunshine           75625.0                       7.611178
# WindGustSpeed     135197.0                       40.03523
# WindSpeed9am      143693.0                      14.043426
# WindSpeed3pm      142398.0                      18.662657
# Humidity9am       142806.0                      68.880831
# Humidity3pm       140953.0                      51.539116
# Pressure9am       130395.0                     1017.64994
# Pressure3pm       130432.0                    1015.255889
# Cloud9am           89572.0                       4.447461
# Cloud3pm           86102.0                        4.50993
# Temp9am           143693.0                      16.990631
# Temp3pm           141851.0                       21.68339
# RainToday         142199.0                       0.224193
# RainTomorrow      142193.0                       0.224181
# RainTomorrow_num  142193.0                       0.224181
#
#                                   min                  25%  \
# Date              2007-11-01 00:00:00  2011-01-11 00:00:00
# MinTemp                          -8.5                  7.6
# MaxTemp                          -4.8                 17.9
# Rainfall                          0.0                  0.0
# Evaporation                       0.0                  2.6
# Sunshine                          0.0                  4.8
# WindGustSpeed                     6.0                 31.0
# WindSpeed9am                      0.0                  7.0
# WindSpeed3pm                      0.0                 13.0
# Humidity9am                       0.0                 57.0
# Humidity3pm                       0.0                 37.0
# Pressure9am                     980.5               1012.9
# Pressure3pm                     977.1               1010.4
# Cloud9am                          0.0                  1.0
# Cloud3pm                          0.0                  2.0
# Temp9am                          -7.2                 12.3
# Temp3pm                          -5.4                 16.6
# RainToday                         0.0                  0.0
# RainTomorrow                      0.0                  0.0
# RainTomorrow_num                  0.0                  0.0
#
#                                   50%                  75%  \
# Date              2013-06-02 00:00:00  2015-06-14 00:00:00
# MinTemp                          12.0                 16.9
# MaxTemp                          22.6                 28.2
# Rainfall                          0.0                  0.8
# Evaporation                       4.8                  7.4
# Sunshine                          8.4                 10.6
# WindGustSpeed                    39.0                 48.0
# WindSpeed9am                     13.0                 19.0
# WindSpeed3pm                     19.0                 24.0
# Humidity9am                      70.0                 83.0
# Humidity3pm                      52.0                 66.0
# Pressure9am                    1017.6               1022.4
# Pressure3pm                    1015.2               1020.0
# Cloud9am                          5.0                  7.0
# Cloud3pm                          5.0                  7.0
# Temp9am                          16.7                 21.6
# Temp3pm                          21.1                 26.4
# RainToday                         0.0                  0.0
# RainTomorrow                      0.0                  0.0
# RainTomorrow_num                  0.0                  0.0
#
#                                   max        std
# Date              2017-06-25 00:00:00        NaN
# MinTemp                          33.9   6.398495
# MaxTemp                          48.1   7.119049
# Rainfall                        371.0    8.47806
# Evaporation                     145.0   4.193704
# Sunshine                         14.5   3.785483
# WindGustSpeed                   135.0  13.607062
# WindSpeed9am                    130.0   8.915375
# WindSpeed3pm                     87.0     8.8098
# Humidity9am                     100.0  19.029164
# Humidity3pm                     100.0  20.795902
# Pressure9am                    1041.0    7.10653
# Pressure3pm                    1039.6   7.037414
# Cloud9am                          9.0   2.887159
# Cloud3pm                          9.0   2.720357
# Temp9am                          40.2   6.488753
# Temp3pm                          46.7    6.93665
# RainToday                         1.0   0.417051
# RainTomorrow                      1.0   0.417043
# RainTomorrow_num                  1.0   0.417043

# %% [markdown]
# # 2. Análise Univariada

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(7, 5))
sns.histplot(df['Humidity3pm'].dropna(), kde=True, color='steelblue')
plt.title('Distribuição de Humidity3pm')
plt.xlabel('Humidity3pm (%)')
plt.ylabel('Frequência')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(7, 5))
sns.histplot(df['Sunshine'].dropna(), kde=True, color='steelblue')
plt.title('Distribuição de Sunshine')
plt.xlabel('Sunshine (horas de sol)')
plt.ylabel('Frequência')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(7, 5))
sns.histplot(df['Cloud3pm'].dropna(), kde=True, color='steelblue')
plt.title('Distribuição de Cloud3pm')
plt.xlabel('Cloud3pm (oktas, 0-8)')
plt.ylabel('Frequência')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Análise Bivariada

# %% [markdown]
# 1. A umidade às 15h (`Humidity3pm`) está associada à chance de chover no dia seguinte?
#
# 2. Dias com menos horas de sol (`Sunshine`) tendem a anteceder chuva no dia seguinte?
#
# 3. A cobertura de nuvens às 15h (`Cloud3pm`) está relacionada à ocorrência de chuva no dia seguinte?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(7, 5))
sns.boxplot(data=df, x='RainTomorrow', y='Humidity3pm', hue='RainTomorrow',
            legend=False, palette='Set2')
plt.title('Humidity3pm x RainTomorrow')
plt.xlabel('RainTomorrow')
plt.ylabel('Humidity3pm (%)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Humidity3pm** (correlação 0,45): dias que antecedem chuva têm umidade às 15h nitidamente mais alta

# %%
df['RainTomorrow_label'] = df['RainTomorrow'].map({0: 'Não', 1: 'Sim'})

# %%
amostra = df.sample(n=2000, random_state=42)

# %%
sns.barplot(data=df, x='RainTomorrow_label', y='Sunshine', hue='RainTomorrow_label',
            legend=False, palette='Set2')
# Out:
# <Axes: xlabel='RainTomorrow_label', ylabel='Sunshine'>

# %%
import numpy as np

plt.figure(figsize=(7, 5))
sns.stripplot(data=amostra, x='Sunshine', y='RainTomorrow_label', hue='RainTomorrow_label',
              legend=False, palette='Set2', alpha=0.3, jitter=0.3)
plt.title('Sunshine x RainTomorrow (dispersão)')
plt.xlabel('Sunshine (horas de sol)')
plt.ylabel('RainTomorrow')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.barplot(data=df_plot, x='RainTomorrow_label', y='Sunshine', hue='RainTomorrow_label',
            legend=False, palette='Set2')
plt.title('Média de Sunshine por RainTomorrow')
plt.xlabel('RainTomorrow')
plt.ylabel('Sunshine médio (horas de sol)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Sunshine** (correlação -0,45): relação inversa clara, menos horas de sol no dia tendem a preceder chuva no dia seguinte. Faz sentido meteorologicamente mais nuvens = menos sol = mais chuva.

# %%
plt.figure(figsize=(7, 5))
sns.boxplot(data=df, x='RainTomorrow_label', y='Cloud3pm', hue='RainTomorrow_label',
            legend=False, palette='Set2')
plt.title('Cloud3pm x RainTomorrow')
plt.xlabel('RainTomorrow')
plt.ylabel('Cloud3pm (oktas, 0-8)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.barplot(data=df, x='RainTomorrow_label', y='Cloud3pm', hue='RainTomorrow_label',
            legend=False, palette='Set2')
plt.title('Média de Cloud3pm por RainTomorrow')
plt.xlabel('RainTomorrow')
plt.ylabel('Cloud3pm médio (oktas, 0-8)')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Cloud3pm** (correlação 0,38): cobertura de nuvens às 15h também mais alta nos dias que antecedem chuva
# (mediana 7 vs 4 oktas), reforçando o padrão da Sunshine.

# %% [markdown]
# # **3. Pré-Processamento**

# %% [markdown]
# ## Featuring - Criando a Coluna Season

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month

def mes_para_estacao(mes):
    if mes in [12, 1, 2]:
        return 'Verao'
    elif mes in [3, 4, 5]:
        return 'Outono'
    elif mes in [6, 7, 8]:
        return 'Inverno'
    else:
        return 'Primavera'

df['Season'] = df['Month'].apply(mes_para_estacao)
df = df.drop(columns=['Date'])

# %% [markdown]
# Criamos a Coluna Season porque entendemos que a estação do ano vai influenciar no nosso target RainTomorrow

# %% [markdown]
# ## Enconding Usando OneHot Enconder

# %%
from sklearn.preprocessing import OneHotEncoder

colunas_categoricas = ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'Season']

encoder = OneHotEncoder(handle_unknown='ignore', drop='first', sparse_output=False)

encoded_array = encoder.fit_transform(df[colunas_categoricas])

df_encoded = pd.DataFrame(
    encoded_array,
    columns=encoder.get_feature_names_out(colunas_categoricas),
    index=df.index
)

df = df.drop(columns=colunas_categoricas)
df = pd.concat([df, df_encoded], axis=1)

print(df.shape)
# Out:
# (145460, 120)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 120 columns):
#  #    Column                     Dtype
# ---   ------                     -----
#  0    MinTemp                    float64
#  1    MaxTemp                    float64
#  2    Rainfall                   float64
#  3    Evaporation                float64
#  4    Sunshine                   float64
#  5    WindGustSpeed              float64
#  6    WindSpeed9am               float64
#  7    WindSpeed3pm               float64
#  8    Humidity9am                float64
#  9    Humidity3pm                float64
#  10   Pressure9am                float64
#  11   Pressure3pm                float64
#  12   Cloud9am                   float64
#  13   Cloud3pm                   float64
#  14   Temp9am                    float64
#  15   Temp3pm                    float64
#  16   RainToday                  float64
#  17   RainTomorrow               float64
#  18   RainTomorrow_num           float64
#  19   RainTomorrow_label         object
#  20   Month                      int32
#  21   Location_Albany            float64
#  22   Location_Albury            float64
#  23   Location_AliceSprings      float64
#  24   Location_BadgerysCreek     float64
#  25   Location_Ballarat          float64
#  26   Location_Bendigo           float64
#  27   Location_Brisbane          float64
#  28   Location_Cairns            float64
#  29   Location_Canberra          float64
#  30   Location_Cobar             float64
#  31   Location_CoffsHarbour      float64
#  32   Location_Dartmoor          float64
#  33   Location_Darwin            float64
#  34   Location_GoldCoast         float64
#  35   Location_Hobart            float64
#  36   Location_Katherine         float64
#  37   Location_Launceston        float64
#  38   Location_Melbourne         float64
#  39   Location_MelbourneAirport  float64
#  40   Location_Mildura           float64
#  41   Location_Moree             float64
#  42   Location_MountGambier      float64
#  43   Location_MountGinini       float64
#  44   Location_Newcastle         float64
#  45   Location_Nhil              float64
#  46   Location_NorahHead         float64
#  47   Location_NorfolkIsland     float64
#  48   Location_Nuriootpa         float64
#  49   Location_PearceRAAF        float64
#  50   Location_Penrith           float64
#  51   Location_Perth             float64
#  52   Location_PerthAirport      float64
#  53   Location_Portland          float64
#  54   Location_Richmond          float64
#  55   Location_Sale              float64
#  56   Location_SalmonGums        float64
#  57   Location_Sydney            float64
#  58   Location_SydneyAirport     float64
#  59   Location_Townsville        float64
#  60   Location_Tuggeranong       float64
#  61   Location_Uluru             float64
#  62   Location_WaggaWagga        float64
#  63   Location_Walpole           float64
#  64   Location_Watsonia          float64
#  65   Location_Williamtown       float64
#  66   Location_Witchcliffe       float64
#  67   Location_Wollongong        float64
#  68   Location_Woomera           float64
#  69   WindGustDir_ENE            float64
#  70   WindGustDir_ESE            float64
#  71   WindGustDir_N              float64
#  72   WindGustDir_NE             float64
#  73   WindGustDir_NNE            float64
#  74   WindGustDir_NNW            float64
#  75   WindGustDir_NW             float64
#  76   WindGustDir_S              float64
#  77   WindGustDir_SE             float64
#  78   WindGustDir_SSE            float64
#  79   WindGustDir_SSW            float64
#  80   WindGustDir_SW             float64
#  81   WindGustDir_W              float64
#  82   WindGustDir_WNW            float64
#  83   WindGustDir_WSW            float64
#  84   WindGustDir_nan            float64
#  85   WindDir9am_ENE             float64
#  86   WindDir9am_ESE             float64
#  87   WindDir9am_N               float64
#  88   WindDir9am_NE              float64
#  89   WindDir9am_NNE             float64
#  90   WindDir9am_NNW             float64
#  91   WindDir9am_NW              float64
#  92   WindDir9am_S               float64
#  93   WindDir9am_SE              float64
#  94   WindDir9am_SSE             float64
#  95   WindDir9am_SSW             float64
#  96   WindDir9am_SW              float64
#  97   WindDir9am_W               float64
#  98   WindDir9am_WNW             float64
#  99   WindDir9am_WSW             float64
#  100  WindDir9am_nan             float64
#  101  WindDir3pm_ENE             float64
#  102  WindDir3pm_ESE             float64
#  103  WindDir3pm_N               float64
#  104  WindDir3pm_NE              float64
#  105  WindDir3pm_NNE             float64
#  106  WindDir3pm_NNW             float64
#  107  WindDir3pm_NW              float64
#  108  WindDir3pm_S               float64
#  109  WindDir3pm_SE              float64
#  110  WindDir3pm_SSE             float64
#  111  WindDir3pm_SSW             float64
#  112  WindDir3pm_SW              float64
#  113  WindDir3pm_W               float64
#  114  WindDir3pm_WNW             float64
#  115  WindDir3pm_WSW             float64
#  116  WindDir3pm_nan             float64
#  117  Season_Outono              float64
#  118  Season_Primavera           float64
#  119  Season_Verao               float64
# dtypes: float64(118), int32(1), object(1)
# memory usage: 132.6+ MB

# %%
df = df.drop(columns=['RainTomorrow_label', 'RainTomorrow_num'])

# %% [markdown]
# Dropamos a 'RainTomorrow_label' que usamos só para plotar os gráficos.

# %% [markdown]
# ## Excluir os Nulos do Target RainTomorrow

# %%
df = df.dropna(subset=['RainTomorrow'])

print(df.shape)
print(df['RainTomorrow'].isnull().sum())
# Out:
# (142193, 118)
# 0

# %% [markdown]
# # **4. Treinamento e Comparação dos Modelos**

# %%
X = df.drop(columns=['RainTomorrow'])
y = df['RainTomorrow']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, stratify=y)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (113754, 117)
# (28439, 117)
# (113754,)
# (28439,)

# %%
X_train_nulos = (X_train.isnull().sum()/X_train.shape[0]).sort_values(ascending=False)*100
X_train_nulos
# Out:
# Sunshine            47.773265
# Evaporation         42.807286
# Cloud3pm            40.147160
# Cloud9am            37.692740
# Pressure9am          9.922288
#                       ...
# WindDir3pm_WSW       0.000000
# WindDir3pm_nan       0.000000
# Season_Outono        0.000000
# Season_Primavera     0.000000
# Season_Verao         0.000000
# Length: 117, dtype: float64

# %% [markdown]
# Vamos imputar os dados usando mediana simples (SimpleImputer(strategy='median')) pra todas as numéricas.

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')

X_train = pd.DataFrame(
    imputer.fit_transform(X_train),
    columns=X_train.columns,
    index=X_train.index
)

X_test = pd.DataFrame(
    imputer.transform(X_test),   # transform, não fit_transform
    columns=X_test.columns,
    index=X_test.index
)

# %% [markdown]
# ## Balanceamento

# %% [markdown]
# Tecnicamente temos um desbalanceamento de 78%/22%
# Para esse trabalho vamos usar o class_weight='balanced'que é mais simples, não mexe nos dados, só ajusta o peso da função de perda pra compensar o desbalanceamento.

# %% [markdown]
# ## Criar os dois Modelos - LogisticRegression e DecisionTree

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

model_reg = LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)
model_tree = DecisionTreeClassifier(class_weight='balanced', max_depth=6, random_state=42)

# %%
model_reg.fit(X_train, y_train)
model_tree.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# DecisionTreeClassifier(class_weight='balanced', max_depth=6, random_state=42)

# %%
previsoes_reg = model_reg.predict(X_test)
previsoes_tree = model_tree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
acuracia_reg = accuracy_score(y_test, previsoes_reg)
print(acuracia_reg)
acuracia_tree = accuracy_score(y_test, previsoes_tree)
print(acuracia_tree)
# Out:
# 0.7907802665353916
# 0.77710186715426

# %%
print(classification_report(y_test, previsoes_tree))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.78      0.85     22064
#          1.0       0.50      0.75      0.60      6375
#
#     accuracy                           0.78     28439
#    macro avg       0.71      0.77      0.72     28439
# weighted avg       0.82      0.78      0.79     28439

# %%
print(classification_report(y_test, previsoes_reg))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.80      0.86     22064
#          1.0       0.52      0.77      0.62      6375
#
#     accuracy                           0.79     28439
#    macro avg       0.72      0.78      0.74     28439
# weighted avg       0.83      0.79      0.80     28439

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(14,8))

plot_tree(
    model_tree,
    feature_names=X.columns,
    class_names= ['Nao', "Sim"],
    filled = True,
    rounded = True,
    fontsize=10
)

plt.show()

# %% [markdown]
# ## ROC AUC

# %%
from sklearn.metrics import RocCurveDisplay
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(7, 6))

RocCurveDisplay.from_estimator(model_reg, X_test, y_test, name='Regressão Logística', ax=ax)
RocCurveDisplay.from_estimator(model_tree, X_test, y_test, name='Árvore de Decisão', ax=ax)

ax.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Aleatório')
ax.set_title('Curva ROC - Regressão Logística vs Árvore de Decisão')
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## PR AUC (Precision-Recall)

# %%
from sklearn.metrics import PrecisionRecallDisplay
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(7, 6))

PrecisionRecallDisplay.from_estimator(model_reg, X_test, y_test, name='Regressão Logística', ax=ax)
PrecisionRecallDisplay.from_estimator(model_tree, X_test, y_test, name='Árvore de Decisão', ax=ax)

ax.set_title('Curva Precision-Recall - Regressão Logística vs Árvore de Decisão')
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ### importando bibliotecas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from imblearn.ensemble import BalancedRandomForestClassifier
import xgboost as xgb
from sklearn.svm import SVC
import lightgbm as lgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, auc
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler

# %%
rf = RandomForestClassifier(
    n_estimators = 100,
    random_state = 42
)

# %%
#Precisamos treinar o modelo com nosso dados de treinamento
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf = rf.predict(X_test)

# %%
y_pred_rf
# Out:
# array([0., 1., 0., ..., 0., 1., 0.])

# %%
accuracy = accuracy_score(y_test, y_pred_rf)
conf_matrix = confusion_matrix(y_test, y_pred_rf)
class_report = classification_report(y_test, y_pred_rf)

# Exibir resultados
print("Acurácia do modelo:", accuracy)
print("\nMatriz de Confusão:\n", conf_matrix)
print("\nRelatório de Classificação:\n", class_report)
# Out:
# Acurácia do modelo: 0.8567460177924681
#
# Matriz de Confusão:
#  [[21166   898]
#  [ 3176  3199]]
#
# Relatório de Classificação:
#                precision    recall  f1-score   support
#
#          0.0       0.87      0.96      0.91     22064
#          1.0       0.78      0.50      0.61      6375
#
#     accuracy                           0.86     28439
#    macro avg       0.83      0.73      0.76     28439
# weighted avg       0.85      0.86      0.84     28439

# %%
# Obter a importância das características
importances = rf.feature_importances_
feature_names = X_train.columns

# Criar um DataFrame com a importância
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Pegar só as top 20 mais importantes
top_n = 20
importance_top = importance_df.head(top_n)

# Plotar a importância
plt.figure(figsize=(10, 8))
sns.barplot(data=importance_top, x='Importance', y='Feature')
plt.title(f'Top {top_n} Características - Random Forest')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## XGBOOST

# %%
# Criar o modelo XGBoost
xgb_model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')
xgb_model.fit(X_train, y_train)

# Fazer previsões
xgb_predictions = xgb_model.predict(X_test)

# Avaliar o modelo
print("Accuracy of XGBoost:", accuracy_score(y_test, xgb_predictions))
print(classification_report(y_test, xgb_predictions))
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [19:10:01] WARNING: /__w/xgboost/xgboost/src/learner.cc:793:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Accuracy of XGBoost: 0.857519603361581
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.95      0.91     22064
#          1.0       0.75      0.55      0.63      6375
#
#     accuracy                           0.86     28439
#    macro avg       0.81      0.75      0.77     28439
# weighted avg       0.85      0.86      0.85     28439

# %% [markdown]
# ## LightGBM

# %%
# Criar o modelo LightGBM
lgb_model = lgb.LGBMClassifier()
lgb_model.fit(X_train, y_train)

# Fazer previsões
lgb_predictions = lgb_model.predict(X_test)

# Avaliar o modelo
print("Accuracy of LightGBM:", accuracy_score(y_test, lgb_predictions))
print(classification_report(y_test, lgb_predictions))
# Out:
# [LightGBM] [Info] Number of positive: 25502, number of negative: 88252
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012706 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2752
# [LightGBM] [Info] Number of data points in the train set: 113754, number of used features: 117
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.224186 -> initscore=-1.241439
# [LightGBM] [Info] Start training from score -1.241439
# Accuracy of LightGBM: 0.8578712331657231
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.95      0.91     22064
#          1.0       0.76      0.54      0.63      6375
#
#     accuracy                           0.86     28439
#    macro avg       0.82      0.74      0.77     28439
# weighted avg       0.85      0.86      0.85     28439

# %% [markdown]
# ## Entre Random Forest, XGBOOST, LightGBM o XGBOOST obteve melhor resultado e vamos melhorar os hiperparâmetros.

# %%
  param_grid_xgb = {
    'n_estimators': [50, 100],       # reduzido de 3 para 2 valores
    'max_depth': [3, 6],             # reduzido de 3 para 2 valores
    'learning_rate': [0.1, 0.3],     # reduzido de 3 para 2 valores
    'subsample': [0.8, 1.0],         # reduzido de 3 para 2 valores
    'colsample_bytree': [0.8, 1.0]   # reduzido de 3 para 2 valores
}
# Agora são 2^5 = 32 combinações em vez de 243

grid_search_xgb = GridSearchCV(
    estimator=xgb.XGBClassifier(eval_metric='logloss', tree_method='hist', random_state=42),
    param_grid=param_grid_xgb,
    scoring='accuracy',
    cv=3,
    verbose=1,
    n_jobs=-1
)

grid_search_xgb.fit(X_train, y_train)

print("Melhores parâmetros encontrados para XGBoost:", grid_search_xgb.best_params_)
print("Melhor acurácia encontrada para XGBoost:", grid_search_xgb.best_score_)

best_xgb_model = grid_search_xgb.best_estimator_
xgb_gs_predictions = best_xgb_model.predict(X_test)

print("Accuracy of XGBoost after Grid Search:", accuracy_score(y_test, xgb_gs_predictions))
print(classification_report(y_test, xgb_gs_predictions))
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# Melhores parâmetros encontrados para XGBoost: {'colsample_bytree': 0.8, 'learning_rate': 0.3, 'max_depth': 6, 'n_estimators': 100, 'subsample': 1.0}
# Melhor acurácia encontrada para XGBoost: 0.858079715878123
# Accuracy of XGBoost after Grid Search: 0.859770034108091
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.95      0.91     22064
#          1.0       0.75      0.56      0.64      6375
#
#     accuracy                           0.86     28439
#    macro avg       0.82      0.75      0.78     28439
# weighted avg       0.85      0.86      0.85     28439

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.9.0-py3-none-any.whl.metadata (15 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.19.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.51)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna) (1.1.3)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.16.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.5.3)
# Downloading optuna-4.9.0-py3-none-any.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 kB 2.9 MB/s eta 0:00:00
# Downloading alembic-1.19.1-py3-none-any.whl (265 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.9/265.9 kB 18.4 MB/s eta 0:00:00
# Downloading colorlog-6.12.0-py3-none-any.whl (12 kB)
# Installing collected packages: colorlog, alembic, optuna
# Successfully installed alembic-1.19.1 colorlog-6.12.0 optuna-4.9.0

# %%
import optuna

# %%
def objective_xgb(trial):
    # Sugerir hiperparâmetros para o XGBoost
    param = {
        'objective': 'binary:logistic',
        'eval_metric': 'logloss',
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 0.5),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.001, 0.1),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.001, 0.1),
        'random_state': 42,
        'n_jobs': -1
    }

    # Inicializar e treinar o modelo XGBoost
    model = xgb.XGBClassifier(**param)
    model.fit(X_train, y_train)

    # Fazer previsões e calcular a acurácia
    y_pred = model.predict(X_test)
    recall = recall_score(y_test, y_pred)

    return recall

# Criar um estudo Optuna e otimizar para XGBoost
study_xgb = optuna.create_study(direction='maximize') # Queremos maximizar o recall
study_xgb.optimize(objective_xgb, n_trials=25) # Rodar 25 tentativas (pode ajustar este número)

# Imprimir os melhores resultados
print("\nMelhor tentativa (XGBoost com Optuna):")
print(f"  Valor objetivo: {study_xgb.best_value:.4f}")
print("  Melhores hiperparâmetros:")
for key, value in study_xgb.best_params.items():
    print(f"    {key}: {value}")
# Out:
# [I 2026-08-08 19:35:34,562] A new study created in memory with name: no-name-cc43e402-cccb-458a-a936-1dab6da8b98b
# [I 2026-08-08 19:35:55,277] Trial 0 finished with value: 0.5874509803921568 and parameters: {'n_estimators': 425, 'learning_rate': 0.1739243273639125, 'max_depth': 10, 'subsample': 0.6449146323131013, 'colsample_bytree': 0.7365543888750996, 'gamma': 0.2880893471673175, 'reg_alpha': 0.03971560617723305, 'reg_lambda': 0.004716359035817392}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:36:06,186] Trial 1 finished with value: 0.5750588235294117 and parameters: {'n_estimators': 444, 'learning_rate': 0.24189611289382856, 'max_depth': 10, 'subsample': 0.9102991771012358, 'colsample_bytree': 0.6674177365591528, 'gamma': 0.4775273806077598, 'reg_alpha': 0.09755685556770981, 'reg_lambda': 0.05068891495167766}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:36:13,592] Trial 2 finished with value: 0.5372549019607843 and parameters: {'n_estimators': 354, 'learning_rate': 0.08820226509794016, 'max_depth': 4, 'subsample': 0.6223848244105458, 'colsample_bytree': 0.7381714652648964, 'gamma': 0.3060483699542653, 'reg_alpha': 0.05912344410952077, 'reg_lambda': 0.06073494797031454}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:36:27,432] Trial 3 finished with value: 0.5871372549019608 and parameters: {'n_estimators': 439, 'learning_rate': 0.18551607384663502, 'max_depth': 9, 'subsample': 0.6658009753889919, 'colsample_bytree': 0.6805412339157725, 'gamma': 0.3383108082511525, 'reg_alpha': 0.03357111028646587, 'reg_lambda': 0.08175866100694107}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:36:33,717] Trial 4 finished with value: 0.5672156862745098 and parameters: {'n_estimators': 277, 'learning_rate': 0.24920341227124693, 'max_depth': 5, 'subsample': 0.9774253137083219, 'colsample_bytree': 0.7761747107336479, 'gamma': 0.1496775457082069, 'reg_alpha': 0.029472884891080776, 'reg_lambda': 0.0641931744039472}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:36:36,242] Trial 5 finished with value: 0.5372549019607843 and parameters: {'n_estimators': 86, 'learning_rate': 0.14905379844305597, 'max_depth': 6, 'subsample': 0.6150904510933732, 'colsample_bytree': 0.6507544785905807, 'gamma': 0.366057447340577, 'reg_alpha': 0.08560898032760304, 'reg_lambda': 0.08284056291786478}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:36:42,274] Trial 6 finished with value: 0.5816470588235294 and parameters: {'n_estimators': 192, 'learning_rate': 0.2005057096414058, 'max_depth': 9, 'subsample': 0.6350474933369163, 'colsample_bytree': 0.8672385208942575, 'gamma': 0.20904640319650925, 'reg_alpha': 0.06186882165576161, 'reg_lambda': 0.06586942274345707}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:36:45,200] Trial 7 finished with value: 0.5190588235294118 and parameters: {'n_estimators': 73, 'learning_rate': 0.1974723668209667, 'max_depth': 4, 'subsample': 0.9042165169736995, 'colsample_bytree': 0.6718125482442513, 'gamma': 0.33764757436314397, 'reg_alpha': 0.0018378676380348441, 'reg_lambda': 0.09935611409093077}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:36:48,924] Trial 8 finished with value: 0.5505882352941176 and parameters: {'n_estimators': 159, 'learning_rate': 0.1339204081893842, 'max_depth': 6, 'subsample': 0.7715504629679459, 'colsample_bytree': 0.7734690772633733, 'gamma': 0.1573013434959668, 'reg_alpha': 0.010869416418214685, 'reg_lambda': 0.09988290282226081}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:36:52,330] Trial 9 finished with value: 0.5422745098039216 and parameters: {'n_estimators': 215, 'learning_rate': 0.27694113021108907, 'max_depth': 3, 'subsample': 0.9168126866238002, 'colsample_bytree': 0.9876228637945265, 'gamma': 0.09763517012550549, 'reg_alpha': 0.012417308401982814, 'reg_lambda': 0.029053357250282817}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:37:05,269] Trial 10 finished with value: 0.5590588235294117 and parameters: {'n_estimators': 496, 'learning_rate': 0.04836143278795341, 'max_depth': 7, 'subsample': 0.75949793703164, 'colsample_bytree': 0.915668536266184, 'gamma': 0.01977701306487306, 'reg_alpha': 0.06862405518607059, 'reg_lambda': 0.004617410965943078}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:37:17,641] Trial 11 finished with value: 0.5829019607843138 and parameters: {'n_estimators': 395, 'learning_rate': 0.15235061003930883, 'max_depth': 9, 'subsample': 0.7131456146851888, 'colsample_bytree': 0.6146508506849105, 'gamma': 0.2648650981723637, 'reg_alpha': 0.037722039191703555, 'reg_lambda': 0.0024671117287355677}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:37:30,199] Trial 12 finished with value: 0.5788235294117647 and parameters: {'n_estimators': 335, 'learning_rate': 0.19704311023437657, 'max_depth': 10, 'subsample': 0.6944974718440253, 'colsample_bytree': 0.7272508643545066, 'gamma': 0.3863751201305969, 'reg_alpha': 0.03765696953229139, 'reg_lambda': 0.02928354875430756}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:37:43,148] Trial 13 finished with value: 0.5750588235294117 and parameters: {'n_estimators': 444, 'learning_rate': 0.10486735532882735, 'max_depth': 8, 'subsample': 0.6893603738698754, 'colsample_bytree': 0.8282669817470474, 'gamma': 0.49496328381792803, 'reg_alpha': 0.04599162009254562, 'reg_lambda': 0.03457118628098523}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:37:56,281] Trial 14 finished with value: 0.5821176470588235 and parameters: {'n_estimators': 465, 'learning_rate': 0.18069221284727036, 'max_depth': 8, 'subsample': 0.8188798169143352, 'colsample_bytree': 0.7142372773167024, 'gamma': 0.41814679475696415, 'reg_alpha': 0.026219436374471508, 'reg_lambda': 0.01619788105330207}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:38:08,933] Trial 15 finished with value: 0.5764705882352941 and parameters: {'n_estimators': 383, 'learning_rate': 0.22837263182866122, 'max_depth': 9, 'subsample': 0.6656734848853545, 'colsample_bytree': 0.802103469403552, 'gamma': 0.28346065474984006, 'reg_alpha': 0.0512607022854471, 'reg_lambda': 0.07992177594276768}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:38:22,314] Trial 16 finished with value: 0.5391372549019607 and parameters: {'n_estimators': 294, 'learning_rate': 0.020676590835178643, 'max_depth': 10, 'subsample': 0.7541468053794613, 'colsample_bytree': 0.6036748330145392, 'gamma': 0.2250483075439604, 'reg_alpha': 0.02207739076951786, 'reg_lambda': 0.04555318843213064}. Best is trial 0 with value: 0.5874509803921568.
# [I 2026-08-08 19:38:34,248] Trial 17 finished with value: 0.587764705882353 and parameters: {'n_estimators': 408, 'learning_rate': 0.29518386581879624, 'max_depth': 8, 'subsample': 0.6025499207282452, 'colsample_bytree': 0.7093783674708055, 'gamma': 0.4035695990886548, 'reg_alpha': 0.07523297286635136, 'reg_lambda': 0.07586797815394879}. Best is trial 17 with value: 0.587764705882353.
# [I 2026-08-08 19:38:46,044] Trial 18 finished with value: 0.5832156862745098 and parameters: {'n_estimators': 394, 'learning_rate': 0.29967376853102823, 'max_depth': 8, 'subsample': 0.6051442952117534, 'colsample_bytree': 0.8454451580111946, 'gamma': 0.4372620081703348, 'reg_alpha': 0.07447743505297777, 'reg_lambda': 0.01558705605429904}. Best is trial 17 with value: 0.587764705882353.
# [I 2026-08-08 19:38:55,176] Trial 19 finished with value: 0.5829019607843138 and parameters: {'n_estimators': 299, 'learning_rate': 0.27804023732635663, 'max_depth': 7, 'subsample': 0.6512623071870024, 'colsample_bytree': 0.8983755502359562, 'gamma': 0.43023937908049875, 'reg_alpha': 0.08389901946996092, 'reg_lambda': 0.0423874924771368}. Best is trial 17 with value: 0.587764705882353.
# [I 2026-08-08 19:39:07,700] Trial 20 finished with value: 0.5675294117647058 and parameters: {'n_estimators': 490, 'learning_rate': 0.08345290193578479, 'max_depth': 7, 'subsample': 0.728388725520343, 'colsample_bytree': 0.7538196759266137, 'gamma': 0.23589482124752398, 'reg_alpha': 0.09531123188998263, 'reg_lambda': 0.015975998488126072}. Best is trial 17 with value: 0.587764705882353.
# [I 2026-08-08 19:39:22,171] Trial 21 finished with value: 0.5807058823529412 and parameters: {'n_estimators': 429, 'learning_rate': 0.17489915561013433, 'max_depth': 9, 'subsample': 0.6676307980425671, 'colsample_bytree': 0.6957692840203148, 'gamma': 0.34851312114309463, 'reg_alpha': 0.0424314327269048, 'reg_lambda': 0.08156194822761602}. Best is trial 17 with value: 0.587764705882353.
# [I 2026-08-08 19:39:42,388] Trial 22 finished with value: 0.5811764705882353 and parameters: {'n_estimators': 355, 'learning_rate': 0.12025105729919427, 'max_depth': 10, 'subsample': 0.6018638761182, 'colsample_bytree': 0.6414035933650032, 'gamma': 0.3143468439769561, 'reg_alpha': 0.05301641814515337, 'reg_lambda': 0.07467258953704688}. Best is trial 17 with value: 0.587764705882353.
# [I 2026-08-08 19:39:54,794] Trial 23 finished with value: 0.5810196078431372 and parameters: {'n_estimators': 417, 'learning_rate': 0.2200266173112007, 'max_depth': 8, 'subsample': 0.6548302486546861, 'colsample_bytree': 0.6842667009479736, 'gamma': 0.3890016520515156, 'reg_alpha': 0.03357450199593658, 'reg_lambda': 0.08738715338467307}. Best is trial 17 with value: 0.587764705882353.
# [I 2026-08-08 19:40:09,445] Trial 24 finished with value: 0.5808627450980393 and parameters: {'n_estimators': 459, 'learning_rate': 0.15919961953920794, 'max_depth': 9, 'subsample': 0.6843114487215946, 'colsample_bytree': 0.710752158921836, 'gamma': 0.2775863148548296, 'reg_alpha': 0.01914136858114363, 'reg_lambda': 0.09084590806809911}. Best is trial 17 with value: 0.587764705882353.
# Melhor tentativa (XGBoost com Optuna):
#   Valor objetivo: 0.5878
#   Melhores hiperparâmetros:
#     n_estimators: 408
#     learning_rate: 0.29518386581879624
#     max_depth: 8
#     subsample: 0.6025499207282452
#     colsample_bytree: 0.7093783674708055
#     gamma: 0.4035695990886548
#     reg_alpha: 0.07523297286635136
#     reg_lambda: 0.07586797815394879

# %%
# Opcional: Treinar o modelo final XGBoost com os melhores hiperparâmetros
best_xgb_model_optuna = xgb.XGBClassifier(**study_xgb.best_params)
best_xgb_model_optuna.fit(X_train, y_train)

y_pred_xgb_optuna = best_xgb_model_optuna.predict(X_test)
optuna_xgb_recall = recall_score(y_test, y_pred_xgb_optuna)
print(f"\nRecall do XGBoost com Optuna (melhores parâmetros): {optuna_xgb_recall:.4f}")
print("Relatório de Classificação do XGBoost com Optuna:\n", classification_report(y_test, y_pred_xgb_optuna))
# Out:
# Recall do XGBoost com Optuna (melhores parâmetros): 0.5823
# Relatório de Classificação do XGBoost com Optuna:
#                precision    recall  f1-score   support
#
#          0.0       0.89      0.93      0.91     22064
#          1.0       0.71      0.58      0.64      6375
#
#     accuracy                           0.85     28439
#    macro avg       0.80      0.76      0.77     28439
# weighted avg       0.85      0.85      0.85     28439
